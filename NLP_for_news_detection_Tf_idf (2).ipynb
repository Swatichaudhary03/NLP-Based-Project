# %%
import numpy as np
import pandas as pd

# %%
fake = pd.read_csv('/content/Fake (1).xls')
true = pd.read_csv('/content/True (1).xls')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake["subject"].value_counts()
# Out:
# subject
# News               9050
# politics           6841
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: count, dtype: int64

# %%
true["subject"].value_counts()
# Out:
# subject
# politicsNews    11272
# worldnews       10145
# Name: count, dtype: int64

# %%
# creating a category for whether fake or not
fake['category'] = 1
true['category'] = 0

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  category
# 0  December 31, 2017         1
# 1  December 31, 2017         1
# 2  December 30, 2017         1
# 3  December 29, 2017         1
# 4  December 25, 2017         1

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  category
# 0  December 31, 2017          0
# 1  December 29, 2017          0
# 2  December 31, 2017          0
# 3  December 30, 2017          0
# 4  December 29, 2017          0

# %%
len(fake)
# Out:
# 23481

# %%
len(true)
# Out:
# 21417

# %%
df=pd.concat([fake,true]).reset_index(drop=True)

# %%
df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# ...

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  category
# 0  December 31, 2017         1
# 1  December 31, 2017         1
# 2  December 30, 2017         1
# 3  December 29, 2017         1
# 4  December 25, 2017         1

# %%
df.value_counts("category")
# Out:
# category
# 1    23481
# 0    21417
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# setting figure size
plt.figure(figsize=(2,2))
sns.countplot(x='category',data=df)
plt.legend()
# Out:
# /tmp/ipython-input-71522823.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='subject',data=df)
plt.legend()
# Out:
# /tmp/ipython-input-100265303.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df=df[['text','category']]
df.head()
# Out:
#                                                 text  category
# 0  Donald Trump just couldn t wish all Americans ...         1
# 1  House Intelligence Committee Chairman Devin Nu...         1
# 2  On Friday, it was revealed that former Milwauk...         1
# 3  On Christmas day, Donald Trump announced that ...         1
# 4  Pope Francis used his annual Christmas Day mes...         1

# %% [markdown]
# Data Cleaning

# %%
df.isna().sum()*100/len(df)
# Out:
# text        0.0
# category    0.0
# dtype: float64

# %%
# checking if there is any empty string in TEXT column
blanks=[]

for index,text in df['text'].items():
  if text.isspace():
    blanks.append(index)

len(blanks)
# Out:
# 631

# %%
blanks
# Out:
# [10923,
#  11041,
#  11190,
#  11225,
#  11236,
#  11241,
#  11247,
#  11249,
#  11267,
#  11268,
#  11283,
#  11284,
#  11285,
#  11289,
#  11290,
#  11292,
#  11295,
#  11296,
#  11301,
#  11303,
#  11304,
#  11305,
#  11309,
#  11314,
#  11317,
#  11319,
#  11322,
#  11330,
#  11334,
#  11335,
#  11340,
#  11343,
#  11348,
#  11351,
#  11352,
#  11357,
#  11371,
#  11373,
#  11374,
#  11382,
#  11397,
#  11402,
#  11403,
#  11409,
#  11410,
#  11412,
#  11415,
#  11419,
#  11421,
#  11427,
#  11431,
#  11432,
#  11440,
#  11448,
#  11450,
#  11453,
#  11462,
#  11464,
#  11465,
#  11472,
#  11473,
#  11475,
#  11478,
#  11489,
#  11491,
#  11493,
#  11494,
#  11501,
#  11505,
#  11507,
#  11520,
#  11531,
#  11532,
#  11533,
#  11538,
#  11542,
#  11547,
#  11549,
#  11551,
#  11559,
#  11563,
#  11581,
#  11585,
#  11589,
#  11590,
#  11614,
#  11624,
#  11625,
#  11627,
#  11631,
#  11636,
#  11637,
#  11643,
#  11650,
#  11658,
#  11661,
#  11672,
#  11679,
#  11681,
#  11684,
# ...

# %%
df['text'][10923]
# Out:
# ' '

# %%
df.shape
# Out:
# (44898, 2)

# %%
df.drop(blanks,inplace=True)
# Out:
# /tmp/ipython-input-1671220260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(blanks,inplace=True)

# %%
df.shape
# Out:
# (44267, 2)

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
## DS Novice

# %%
import nltk
nltk.download('wordnet')
lemma = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
from nltk.corpus import stopwords
import nltk
import spacy

#Download NLTK stopwords
nltk.download("stopwords")

#Load spacy model
nlp = spacy.blank("en")

#Stopwords from spacy

list1= nlp.Defaults.stop_words
print("Number of spacy stopwords:", len(list1))

#Stopwords from NLTK

list2= set(stopwords.words('english'))
print("Number of NLTK stopwords:", len(list2))

#Combine both stopwords lists
Stopwords= set(list1 | list2)
print("Total combined stopwords:", len (Stopwords))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Number of spacy stopwords: 326
# Number of NLTK stopwords: 198
# Total combined stopwords: 401

# %%
# text cleaning function
#text cleaning function
def clean_text(text):

    """
    It takes text as an input and clean it by applying several methods

    """

    string = ""

    #lower casing
    text=text.lower()

    #simplifying text
    text=re.sub(r"i'm","i am",text)
    text=re.sub(r"he's","he is",text)
    text=re.sub(r"she's","she is",text)
    text=re.sub(r"that's","that is",text)
    text=re.sub(r"what's","what is",text)
    text=re.sub(r"where's","where is",text)
    text=re.sub(r"\'ll"," will",text)
    text=re.sub(r"\'ve"," have",text)
    text=re.sub(r"\'re"," are",text)
    text=re.sub(r"\'d"," would",text)
    text=re.sub(r"won't","will not",text)
    text=re.sub(r"can't","cannot",text)

    #removing any special character
    text=re.sub(r"[-()\"#!@$%^&*{}?.,:]"," ",text)
    text=re.sub(r"\s+"," ",text)
    text=re.sub('[^A-Za-z0-9]+',' ', text)

    for word in text.split():
        if word not in Stopwords:
            string+=lemma.lemmatize(word)+" "

    return string

# %%
# cleaning the whole data
df['text']=df['text'].apply(clean_text)
# Out:
# /tmp/ipython-input-1148755160.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text']=df['text'].apply(clean_text)

# %%
df['text'][10]
# Out:
# 'centerpiece donald trump campaign presidency white supremacist way public feud involve people color favorite target course player national football league dare exercise amendment right kneeling national anthem protest racist police brutality person figured racism bad business orange overlord elected founder pizza chain papa john man right history number issue plus pizza suck decided complain player protesting sale dropped turn racism pay know corporation line papa john schnatter longer ceo hack pizza chain breaking papa john founder john schnatter step ceo announcement come week criticized nfl protest ap business news apbusiness december 21 2017the thing people certainly allowed political opinion realize opinion come dire consequence especially business trying garner sale support people presume goal ceo know pressure shareholder public outcry boycott nfl stepping right know gone future ceo run company inclusive diverse fabric america guiding symbol nation statue liberty bigot like t
# ...

# %%
clean_text(df['text'][10])
# Out:
# 'centerpiece donald trump campaign presidency white supremacist way public feud involve people color favorite target course player national football league dare exercise amendment right kneeling national anthem protest racist police brutality person figured racism bad business orange overlord elected founder pizza chain papa john man right history number issue plus pizza suck decided complain player protesting sale dropped turn racism pay know corporation line papa john schnatter longer ceo hack pizza chain breaking papa john founder john schnatter step ceo announcement come week criticized nfl protest ap business news apbusiness december 21 2017the thing people certainly allowed political opinion realize opinion come dire consequence especially business trying garner sale support people presume goal ceo know pressure shareholder public outcry boycott nfl stepping right know gone future ceo run company inclusive diverse fabric america guiding symbol nation statue liberty bigot like t
# ...

# %%
# cleaning whole data
df['text']=df['text'].apply(clean_text)
# Out:
# /tmp/ipython-input-1998788798.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text']=df['text'].apply(clean_text)

# %%
df['text']
# Out:
# 0        donald trump wish american happy new year leav...
# 1        house intelligence committee chairman devin nu...
# 2        friday revealed milwaukee sheriff david clarke...
# 3        christmas day donald trump announced work foll...
# 4        pope francis annual christmas day message rebu...
#                                ...
# 44893    brussels reuters nato ally tuesday welcomed pr...
# 44894    london reuters lexisnexis provider legal regul...
# 44895    minsk reuters shadow disused soviet era factor...
# 44896    moscow reuters vatican secretary state cardina...
# 44897    jakarta reuters indonesia buy 11 sukhoi fighte...
# Name: text, Length: 44267, dtype: object

# %% [markdown]
# Word Cloud

# %%
from wordcloud import WordCloud

# %%
# True news
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Assuming df is a dataframe containing the text and category column
plt.figure(figsize=(20, 20))
wc = WordCloud(max_words=500, width=1600, height=800, background_color='white').generate(' '.join(df[df['category'] == 0]['text']))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# creating more intuitive wordcloud

# pil is pillow and used for image manipulation
from PIL import Image

# %%
# creating a mask of thumb
thumb="/content/thumbs-up (1).png"
icon=Image.open(thumb)
mask=Image.new(mode="RGB",size=icon.size,color=(255,255,255))
mask.paste(icon,box=icon)

# %%
# true news
plt.figure(figsize=(10, 10))
wc = WordCloud(max_words=500, width=1600, height=800, background_color='white', mask=np.array(mask)).generate(' '.join(df[df['category'] == 0]['text']))

wc.generate(' '.join(df[df['category'] == 0]['text']))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# creating word cloud using skull image for fake news which depict that fake news are dangerous
skull="/content/skull-icon (1).png"
icon=Image.open(skull)
mask=Image.new(mode="RGB",size=icon.size,color=(255,255,255))
mask.paste(icon,box=icon)

rgb_array=np.array(mask)

# %%
# fake news

plt.figure(figsize=(10, 10))
wc = WordCloud(max_words=500, width=1600, height=800, background_color='white', mask=np.array(mask)).generate(' '.join(df[df['category'] == 0]['text']))

wc.generate(' '.join(df[df['category'] == 1]['text']))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Feature extraction and Model building

# %%
from sklearn.model_selection import train_test_split

x=df['text']
y=df['category']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)
#

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
x_train_tfidf = vectorizer.fit_transform(x_train)
x_test_tfidf = vectorizer.transform(x_test)

# %%
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', LinearSVC())])

text_clf.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
y_pred=text_clf.predict(x_test)

# %%
from sklearn import metrics

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7047
#            1       0.99      0.99      0.99      7562
#
#     accuracy                           0.99     14609
#    macro avg       0.99      0.99      0.99     14609
# weighted avg       0.99      0.99      0.99     14609

# %%
print(metrics.confusion_matrix(y_test,y_pred))
# Out:
# [[6998   49]
#  [  50 7512]]

# %%
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9932233554658088
